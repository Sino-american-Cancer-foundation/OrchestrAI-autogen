# %%
from probill.utils import AppConfig
from autogen_ext.models.openai import OpenAIChatCompletionClient
config = AppConfig.load("/workspaces/OrchestrAI-autogen/python/packages/probill/tests/distributing_agents/config.yaml")
model_client = config.client_config

base_model = OpenAIChatCompletionClient(**model_client)
print("Base model created:", base_model, flush=True)
print(type(base_model), flush=True)
# Out:
# Config section: {'host': {'hostname': '0.0.0.0', 'port': 50060}, 'group_chat_manager': {'topic_type': 'group_chat', 'max_rounds': 3, 'config_override': '_type.GroupChatManagerConfig'}, 'ui_agent': {'topic_type': 'ui_events', 'artificial_stream_delay_seconds': {'min': 0.05, 'max': 0.1}, 'config_override': '_type.UIAgentConfig'}}
# Base model created: <autogen_ext.models.openai._openai_client.OpenAIChatCompletionClient object at 0x7e2ec8132900>
# <class 'autogen_ext.models.openai._openai_client.OpenAIChatCompletionClient'>

# %%
y1 = load_yaml_file("./test.yaml")
print(json.dumps(y1, indent=2))
# Out:
# {
#   "PageLogger": {
#     "level": "DEBUG",
#     "path": "./pagelogs/teachability"
#   },
#   "client": {
#     "model": "qwen2.5-coder:32b-instruct-q5_0",
#     "base_url": "http://10.0.40.49:11434/v1",
#     "api_key": "sk-xxx",
#     "model_info": {
#       "vision": false,
#       "function_calling": true,
#       "json_output": true,
#       "family": "Unknown",
#       "structured_output": true
#     },
#     "temperature": 0.8,
#     "max_completion_tokens": 4096,
#     "presence_penalty": 0.0,
#     "frequency_penalty": 0.0,
#     "top_p": 1.0,
#     "max_retries": 65535
#   },
#   "Apprentice": {
#     "name_of_agent_or_team": "AssistantAgent",
#     "disable_prefix_caching": 1,
#     "MemoryController": {
#       "max_train_trials": 10,
#       "max_test_trials": 3,
#       "MemoryBank": {
#         "path": "./memory_bank/teachability",
#         "relevance_conversion_threshold": 1.7,
#         "n_results": 25,
#         "distance_threshold": 100
#       }
#     }
# ...
